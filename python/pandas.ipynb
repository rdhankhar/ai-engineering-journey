# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
# All basics
import pandas as pd 
df = pd.read_csv(r"C:\Users\ASUS\DA Journey\train.csv")

# print("dataset shape:", df.shape)
# df.head(10)
# print("columns names:", df.columns.tolist())
# print("\n data types:",df.dtypes)
# print("\n basic stastics :")
# df.describe()
# print("\n dataset info")
# df.info()
# df['Age']
# print("current columns " , df.columns.tolist() )
# df[['Name' , 'Age' , 'Survived']]
df[df['Age'] >30]
df[df['Survived'] == 1]
# Out:
# dataset shape: (926, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# Dataframes

import pandas as pd 

data = { "Name" : ["Rahul" ,"Gourav","Tarique"],
         "Age" : [ 20 , 19 , 18] }

df = pd.DataFrame(data, index = ["employee 1","employee 2","employee 3"])

df["Job"] = ["AI engineer" , "Data scientist", "Software engineer"]

# Adding new rows

new_rows = pd.DataFrame([{"Name" : "Harsh" , "Age" : 17 , "Job" : "Ml engineer"},{"Name" : "Sahil" , "Age" : 21 , "Job" : "Game developer"
                                                                                 }], index = ["employee 4","employee 5"])

df  = pd.concat([df , new_rows])
#print(df.loc["employee 1"])
print(df)
# Out:
#                Name  Age                Job
# employee 1    Rahul   20        AI engineer
# employee 2   Gourav   19     Data scientist
# employee 3  Tarique   18  Software engineer
# employee 4    Harsh   17        Ml engineer
# employee 5    Sahil   21     Game developer

# %%
# Series 
import pandas as pd
calories = { "Day 1" : 2300 , "Day 2" : 2700 , "Day 3" : 2900 }
# data = [100.0,110.3,108.05,200,500,230]

# demons = ["Bulbasur","Lvysaur","Venusaur","Charmander","Charmeleon","Charizard"]

# series = pd.Series(data , index = ["apartment 1 =","apartment 2 =","apartment 3 =" ])
#series = pd.Series(data , index = ["a","b","c","d","e","f"])
series = pd.Series(calories)

# series = pd.Series(demons, index = ["1","2","3","4","5","6"])

#series.loc["c"] = 200
# print(series.loc["c"])
# series.iloc[0] = 500
# print(series.iloc[0])
# series.iloc[0] += 200
# print(series.iloc[0])
# print(series[series > 2500])

print(series)
# Out:
# Day 1    2300
# Day 2    2700
# Day 3    2900
# dtype: int64

# %%
#Importing

import pandas as pd

df = pd.read_csv(r"C:\Users\ASUS\DA Journey\train.csv", index_col = "Name")

#df = pd.read_csv(r"C:\Users\ASUS\DA Journey\train.csv")

# df.head(10)
# print(df.to_string())

#display(df.head(60))

# selection by columns

# print(df["Name"].head(10))
# print(df[["Name","Sex","Age","Survived"]].to_string())

# selection by rows

# print(df.loc[["West, Miss. Constance Mirium","Uruchurtu, Don. Manuel E"]])
#df[df.index.str.contains("West", case=False)]
# #df[df.index.str.contains("Uruchurtu", case=False)]
# print(df.loc["Uruchurtu, Don. Manuel E":"West, Miss. Constance Mirium", ["Age", "Sex"]])
# print(df.iloc[0:11:2, 0:3])

Passenger = input("Enter a passenger name :")

try:
    print(df.loc[Passenger])
except KeyError:
    print(f"{Passenger} not found")
# Out:
# Enter a passenger name : rahul
# rahul not found

# %%
# Filtering 

import pandas as pd 
df = pd.read_csv(r"C:\Users\ASUS\DA Journey\train.csv")

#df.head(10)

# Age_data = df[df["Age"] >= 80 ]
# Fare_data = df[df["Fare"] >= 500 ]
# Survived_data = df[df["Survived"] == 1 ]

# age_sur = df[(df["Age"] >= 50 ) | 
#             (df["Survived"] == 1 )]

age_sur = df[(df["Age"] >= 50 ) & 
            (df["Survived"] == 1 )]

print(age_sur)
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 259          260         1       2
# 268          269         1       1
# 275          276         1       1
# 299          300         1       1
# 366          367         1       1
# 449          450         1       1
# 458          459         1       2
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 526          527         1       2
# 570          571         1       2
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 630          631         1       1
# 647          648         1       1
# 660          661         1       1
# 765          766         1       1
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# ...

# %%
# Aggregation 

import pandas as pd
df = pd.read_csv(r"C:\Users\ASUS\DA Journey\train.csv")

# print(df.mean(numeric_only = True))
# print(df.sum(numeric_only = True))
# print(df.min(numeric_only = True))
# print(df.max(numeric_only = True))
# print(df.count())

# column
# print(df[["Age","Fare"]].mean())
# print(df["Fare"].sum())
# print(df["Age"].min())
# print(df["Age"].max())
# print(df["Age"].count())

#Groupby

Group = df.groupby("Pclass")

print("survival by gender ")
print(df.groupby('Sex')['Survived'].mean() )

print("\nsurvival by Pclass ")
print(df.groupby('Pclass')['Survived'].mean() )

print("\n average survival by Age ")
print(df.groupby('Survived')['Age'].mean() )

print(Group["Fare"].mean())
print(Group["Fare"].max())
print(Group["Fare"].min())
print(Group["Fare"].sum())
print(Group["Fare"].count())
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64
# Pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: Fare, dtype: float64
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Fare, dtype: int64

# %%
# Data cleaninng
import pandas as pd
df = pd.read_csv(r"C:\Users\Asus\Da Journey\train.csv")

# 1. Drop irrelevant columns
# df = df.drop(columns = ["SibSp","Parch","Embarked","Sex"])

# 2. Handle missing data
# df = df.dropna(subset = ["Age"])
# df = df.fillna({"Age " : 25})
# df['Age'] .fillna (df['Age'].median(), inplace = True)
# df.drop (columns = ['Cabin'] , inplace = True )
# df.dropna (subset = ['Embarked'], inplace = True )
# df["Age"] = df["Age"].fillna(25)
# df['Age'] = df['Age'].fillna (df['Age'].median() )
# df = df.dropna (subset = ['Embarked'] )

# print("missing values after cleaning ")
# print(df.isnull().sum() )
# df.isnull().sum()
# df["Age"].isnull().sum()

# df["Age"] = df["Age"].fillna(25)
# df.head(50)

# 3. Fix inconsistent values
# df["Sex"] = df["Sex"].replace({"male" : "MALE", 
#                                "female" : "FEMALE"})

# 4. Standardize text
# df["Name"] = df["Name"].str.lower()
# df["Name"] = df["Name"].str.upper()

# 5. Fix data types
# df["Survived"] = df["Survived"].astype(bool)

# 6. Remove duplicate values
df = df.drop_duplicates()


print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
